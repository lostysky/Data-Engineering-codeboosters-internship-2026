# %% [markdown]
# <a href="https://colab.research.google.com/github/lostysky/Data-Engineering-codeboosters-internship-2026/blob/main/Day_04__M.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
a = pd.read_csv("SOCR-HeightWeight.csv")

# %%
a.head()
# Out:
#    Index  Height(Inches)  Weight(Pounds)
# 0      1        65.78331        112.9925
# 1      2        71.51521        136.4873
# 2      3        69.39874        153.0269
# 3      4        68.21660        142.3354
# 4      5        67.78781        144.2971

# %%
a.isnull().sum()
# Out:
# Index             0
# Height(Inches)    0
# Weight(Pounds)    0
# dtype: int64

# %%
a.isnull().any()
# Out:
# Index             False
# Height(Inches)    False
# Weight(Pounds)    False
# dtype: bool

# %%
x=a[["Height(Inches)"]]
x
# Out:
#        Height(Inches)
# 0            65.78331
# 1            71.51521
# 2            69.39874
# 3            68.21660
# 4            67.78781
# ...               ...
# 24995        69.50215
# 24996        64.54826
# 24997        64.69855
# 24998        67.52918
# 24999        68.87761
#
# [25000 rows x 1 columns]

# %%
y=a[["Weight(Pounds)"]]
y
# Out:
#        Weight(Pounds)
# 0            112.9925
# 1            136.4873
# 2            153.0269
# 3            142.3354
# 4            144.2971
# ...               ...
# 24995        118.0312
# 24996        120.1932
# 24997        118.2655
# 24998        132.2682
# 24999        124.8742
#
# [25000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
print("X train")
x_train
# Out:
# X train
#        Height(Inches)
# 18822        67.54277
# 933          67.66400
# 19417        68.08132
# 24237        68.63362
# 6908         68.76882
# ...               ...
# 17650        62.67320
# 22271        64.94584
# 10393        66.28166
# 19572        66.36876
# 14573        66.94490
#
# [20000 rows x 1 columns]

# %%
print("Y train")
y_train
# Out:
# Y train
#        Weight(Pounds)
# 18822        121.0405
# 933          132.5153
# 19417        123.9994
# 24237        128.3377
# 6908         124.6462
# ...               ...
# 17650        121.4203
# 22271        104.0162
# 10393        132.7775
# 19572        122.2946
# 14573        129.0043
#
# [20000 rows x 1 columns]

# %%
print("X test")
x_test
# Out:
# X test
#        Height(Inches)
# 22394        67.20582
# 17764        69.83556
# 20942        68.84252
# 24037        69.11634
# 2587         70.12002
# ...               ...
# 11608        65.08819
# 3274         66.99259
# 9210         69.67952
# 24544        66.45348
# 16643        65.39009
#
# [5000 rows x 1 columns]

# %%
print("Y test")
y_test
# Out:
# Y test
#        Weight(Pounds)
# 22394        112.2300
# 17764        140.1353
# 20942        126.0857
# 24037        135.7018
# 2587         137.7196
# ...               ...
# 11608        129.1596
# 3274         122.1147
# 9210         138.7123
# 24544        122.2987
# 16643        131.0900
#
# [5000 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 8.1472583504863

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 103.36878173284423

# %%
r2_score(y_test,y_pred)
# Out:
# 0.25288515695983604

# %%
import joblib

# %%
joblib.dump(model, "linear.pkl")
# Out:
# ['linear.pkl']

# %%
import joblib

# %%
a=joblib.load("linear.pkl")

# %%
a.predict([[100]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[225.52951861]])

# %% [markdown]
# # practice question

# %%
import pandas as pd
df=pd.read_csv('data.csv')

# %%
df.head(5)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
x=df[['bedrooms','bathrooms','sqft_living','sqft_lot','floors','waterfront','view','condition','sqft_above','sqft_basement','yr_built','yr_renovated']]
y=df[['price']]

# %%
df.isnull().any()
# Out:
# date             False
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront       False
# view             False
# condition        False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated     False
# street           False
# city             False
# statezip         False
# country          False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
x_train
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 3241       2.0       2.00         1180      9265     1.0           0     0
# 3639       3.0       1.75         2200     14630     1.5           0     1
# 514        4.0       3.25         3680      5759     2.0           0     0
# 1914       3.0       1.50         2080      5244     1.0           0     0
# 3864       5.0       2.50         2160      7737     2.0           0     0
# ...        ...        ...          ...       ...     ...         ...   ...
# 1916       5.0       2.00         1750     10284     1.0           0     0
# 184        4.0       3.00         2450     10117     1.0           0     0
# 3845       3.0       1.75         2680      8625     1.0           0     0
# 1561       4.0       1.75         1700      7800     1.0           0     0
# 148        5.0       3.50         4490      6000     2.0           0     0
#
#       condition  sqft_above  sqft_basement  yr_built  yr_renovated
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
model.predict(x_test)
# Out:
# array([[ 678848.45313675],
#        [ 520924.35493471],
#        [ 335972.06727849],
#        [ 668853.19664025],
#        [ 656688.60207645],
#        [ 811193.85276393],
#        [ 616180.89685433],
#        [ 564504.74677632],
#        [ 318265.79557509],
#        [ 832682.38416789],
#        [ 254027.43979721],
#        [ 364102.54552816],
#        [ 568280.38916824],
#        [ 394228.37465261],
#        [ 925826.75935203],
#        [ 428483.42533208],
#        [ 440010.62822582],
#        [ 605462.34448792],
#        [ 508836.42482421],
#        [1142543.11046256],
#        [ 496058.06684028],
#        [ 280188.51443816],
#        [ 821720.95287973],
#        [ 447740.62371952],
#        [ 897014.89261137],
#        [1001573.87729459],
#        [ 466650.37378274],
#        [ 301035.36421237],
#        [ 226108.71037025],
#        [ 544151.43075204],
#        [ 668307.41252847],
#        [ 707858.59670159],
#        [ 871419.44615248],
#        [ 586789.2455105 ],
# ...

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 163393.08902736125

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 65434374374.42693

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4235370347208216
